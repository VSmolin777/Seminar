# %% [markdown]
# ### Новый ноутбук тест

# %% [markdown]
# Проба

# %% [markdown]
# # Новый раздел

# %%
# !pip install pandas -q

# %%
import pandas as pd

# %%
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

# %%
from tensorflow.keras.layers import Dense
model.add(Dense(32, input_dim=10))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model
# Out:
# <Sequential name=sequential, built=True>

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam'  )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           352 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352 (1.38 KB)
#  Trainable params: 352 (1.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = Sequential()
model.add(Dense(32, input_dim=10))
model.add(Dense(5))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 32)             │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 523 (2.04 KB)
#  Trainable params: 523 (2.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.datasets import mnist     # Библиотека с базой рукописных цифр
from tensorflow.keras.models import Sequential  # Подключение класса создания модели Sequential
from tensorflow.keras.layers import Dense       # Подключение класса Dense - полносвязный слой
from tensorflow.keras import utils              # Утилиты для подготовки данных
import numpy as np                              # Работа с массивами
import matplotlib.pyplot as plt                 # Отрисовка изображений

# Отрисовка изображений в ячейках ноутбука
# %matplotlib inline

# %%
# Загрузка из облака данных Mnist
(x_train_org, y_train_org), (x_test_org, y_test_org) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Вывод формы данных для обучения
x_train_org.shape
# Out:
# (60000, 28, 28)

# %%
# Номер картинки
n = 20065

# Отрисовка картинки
plt.imshow(x_train_org[n], cmap='gray')

# Вывод n-й картинки
plt.show()

# %%
# Вывод метки класса для n-го изображения
print(y_train_org[n])
# Out:
# 2

# %%
# Изменение формы входных картинок с 28х28 на 784
# первая ось остается без изменения, остальные складываются в вектор
x_train = x_train_org.reshape(x_train_org.shape[0], -1)
x_test = x_test_org.reshape(x_test_org.shape[0], -1)

# Проверка результата
print(f'Форма обучающих данных: {x_train_org.shape} -> {x_train.shape}')
print(f'Форма  тестовых данных: {x_test_org.shape} -> {x_test.shape}')
# Out:
# Форма обучающих данных: (60000, 28, 28) -> (60000, 784)
# Форма  тестовых данных: (10000, 28, 28) -> (10000, 784)

# %%
# Нормализация входных картинок
# Преобразование x_train в тип float32 (числа с плавающей точкой) и нормализация
x_train = x_train.astype('float32') / 255.

# Преобразование x_test в тип float32 (числа с плавающей точкой) и нормализация
x_test = x_test.astype('float32') / 255.

# %%
# Задание константы количества распознаваемых классов
CLASS_COUNT = 10

# Преобразование ответов в формат one_hot_encoding
y_train = utils.to_categorical(y_train_org, CLASS_COUNT)
y_test = utils.to_categorical(y_test_org, CLASS_COUNT)

# %%
# Вывод формы массива меток
print(y_train_org.shape)
# Out:
# (60000,)

# %%
model.add(Dense(400, activation='relu'))

# %%
# Добавление полносвязного слоя с количеством нейронов по числу классов с softmax-активацией
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
from tensorflow import keras

# Очистка сессии и сброс счетчика имен слоев
keras.backend.clear_session()

# Создание последовательной модели
model = Sequential()

# Добавление полносвязного слоя на 400 нейронов с relu-активацией
model.add(Dense(400, input_dim=784, activation='selu'))
# Добавление полносвязного слоя на 100 нейронов с relu-активацией
model.add(Dense(60, input_dim=400, activation='mish'))

# Добавление полносвязного слоя на 300 нейронов с relu-активацией
model.add(Dense(300, activation='softplus'))

# Добавление полносвязного слоя с количеством нейронов по числу классов с softmax-активацией
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Компиляция модели
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Вывод структуры модели
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 400)            │       314,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 60)             │        24,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 300)            │        18,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         3,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 359,370 (1.37 MB)
#  Trainable params: 359,370 (1.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
model.fit(x_train,        # обучающая выборка, входные данные
          y_train,        # обучающая выборка, выходные данные
          batch_size=128, # кол-во примеров, которое обрабатывает нейронка перед одним изменением весов
          epochs=15,      # количество эпох, когда нейронка обучается на всех примерах выборки
          verbose=1)      # 0 - не визуализировать ход обучения, 1 - визуализировать
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.8478 - loss: 0.5150
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9603 - loss: 0.1308
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9705 - loss: 0.0940
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9773 - loss: 0.0696
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9797 - loss: 0.0584
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9852 - loss: 0.0460
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9870 - loss: 0.0407
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9903 - loss: 0.0288
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9912 - loss: 0.0260
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9918 - loss: 0.0241
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9925 - loss: 0.0220
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9918 - loss: 0.0224
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9938 - loss: 0.0193
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9935 - loss: 0.0199
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9943 - loss: 0.0164

# %%
model.save_weights('model.weights.h5')
model.load_weights('model.weights.h5')
